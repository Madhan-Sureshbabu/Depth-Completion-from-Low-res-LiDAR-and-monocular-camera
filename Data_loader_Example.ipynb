# %%
from data_read_old import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #  Read 64 line LiDAR

# %%
data_loader=Data_load(input_line=64)

# %%
lidar_batch,gt_batch,img_batch=data_loader.read_batch(2)

# %%
plt.imshow(lidar_batch[0,:,:,0])
plt.show()
plt.imshow(gt_batch[0,:,:,0])
plt.show()
plt.imshow(img_batch[0,:,:,:3])
plt.show()

# %% [markdown]
# #  Read 32 line LiDAR

# %%
data_loader=Data_load(input_line=32)

# %%
lidar_batch,gt_batch,img_batch=data_loader.read_batch(1)

# %%
plt.imshow(lidar_batch[0,:,:,0])
plt.show()
plt.imshow(gt_batch[0,:,:,0])
plt.show()
plt.imshow(img_batch[0,:,:,:3])
plt.show()

# %% [markdown]
# #  Read 16 line LiDAR

# %%
data_loader=Data_load(input_line=16)

# %%
lidar_batch,gt_batch,img_batch=data_loader.read_batch(1)

# %%
plt.imshow(lidar_batch[0,:,:,0])
plt.show()
plt.imshow(gt_batch[0,:,:,0])
plt.show()
plt.imshow(img_batch[0,:,:,:3])
plt.show()
